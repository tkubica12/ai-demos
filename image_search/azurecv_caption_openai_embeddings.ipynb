# %% [markdown]
# # Get captions, dense captions and tags from Azure Computer Vision

# %%
# !pip install azure-ai-vision --user

# %%
# imports
import requests
import os
from dotenv import load_dotenv
import pandas as pd
import azure.ai.vision as sdk
import time

# %%
# Load envs
load_dotenv('.env')

# Azure Computer Vision
key = os.getenv("azure_cv_key")
endpoint = os.getenv("azure_cv_endpoint")

# Images to process
image_dir = './val2017/'

# Get Azure Computer Vision client
service_options = sdk.VisionServiceOptions(endpoint, key)

# %%
def analyze_image(imagefile):
    # Set source file
    vision_source = sdk.VisionSource(filename=imagefile)

    # Set analysis options (enable features)
    analysis_options = sdk.ImageAnalysisOptions()

    analysis_options.features = (
        sdk.ImageAnalysisFeature.CAPTION |
        # sdk.ImageAnalysisFeature.DENSE_CAPTIONS |
        sdk.ImageAnalysisFeature.TAGS
    )

    # Analyze the image
    image_analyzer = sdk.ImageAnalyzer(service_options, vision_source, analysis_options)
    result = image_analyzer.analyze()

    return result

# %%
df = pd.DataFrame()
num_files = len(os.listdir(image_dir))

# Iterate over images
for i, filename in enumerate(os.listdir(image_dir)):
    print(f"{i} out of {num_files} - {filename}")

    # Analyze image with retries
    for retries in range(10):
        result = analyze_image(image_dir + filename)
        if result.reason == sdk.ImageAnalysisResultReason.ANALYZED:
            break # Success
        print(f"Will retry {filename} for {retries+1} time")
        if retries == 9:
            raise Exception(f"Failed to analyze {filename} after 10 retries")
        time.sleep(63)
    
    # Parse results
    caption = result.caption.content
    # object_captions = ", ".join(set(object.content for object in result.dense_captions))
    tags = ", ".join(set(object.name for object in result.tags))

    # Store results
    result = { "filename": filename, "caption": caption, "tags": tags }
    # result = { "filename": filename, "caption": caption, "object_captions": object_captions, "tags": tags }
    row = pd.DataFrame(result, index=[0])
    df = pd.concat([df, row], axis=0)
    print(f"---> {caption}")
# Out:
# 0 out of 5000 - 000000000139.jpg
# ---> a woman standing in a kitchen
# 1 out of 5000 - 000000000285.jpg
# ---> a bear sitting in the grass
# 2 out of 5000 - 000000000632.jpg
# ---> a bedroom with a large window
# 3 out of 5000 - 000000000724.jpg
# ---> a stop sign on a pole
# 4 out of 5000 - 000000000776.jpg
# ---> a group of teddy bears
# 5 out of 5000 - 000000000785.jpg
# ---> a woman skiing on the snow
# 6 out of 5000 - 000000000802.jpg
# ---> a kitchen with white appliances
# 7 out of 5000 - 000000000872.jpg
# ---> a baseball player running to base
# 8 out of 5000 - 000000000885.jpg
# ---> a man holding a tennis racket
# 9 out of 5000 - 000000001000.jpg
# ---> a group of people posing for a photo
# 10 out of 5000 - 000000001268.jpg
# ---> a couple of people taking a picture of a swan
# 11 out of 5000 - 000000001296.jpg
# ---> a woman looking at a cell phone
# 12 out of 5000 - 000000001353.jpg
# ---> a group of children riding a train
# 13 out of 5000 - 000000001425.jpg
# ---> a sandwich on a plate
# 14 out of 5000 - 000000001490.jpg
# ---> a person on a surfboard in the water
# 15 out of 5000 - 000000001503.jpg
# ---> a computer on a desk
# 16 out of 5000 - 000000001532.jpg
# ---> a freeway with many cars and signs
# 17 out of 5000 - 000000001584.jpg
# ---> a red double decker bus on a street
# 18 out of 5000 - 000000001675.jpg
# ---> a cat lying in a laptop
# 19 out of 5000 - 000000001761.jpg
# ---> an airplane flying over a bridge
# 20 out of 5000 - 000000001818.jpg
# ---> a baby zebra nursing from its mother
# 21 out of 5000 - 000000001993.jpg
# ---> a bed and chair in a bedroom
# 22 out of 5000 - 000000002006.jpg
# ---> a purple bus on the street
# 23 out of 5000 - 000000002149.jpg
# ---> a bowl of green apples
# 24 out of 5000 - 000000002153.jpg
# ---> a baseball player swinging his bat
# 25 out of 5000 - 000000002157.jpg
# ---> a cake with berries on top of a plate
# 26 out of 5000 - 000000002261.jpg
# ---> a man on a surfboard in the ocean
# 27 out of 5000 - 000000002299.jpg
# ---> a group of children posing for a photo
# 28 out of 5000 - 000000002431.jpg
# ---> a piece of bread on a plate
# 29 out of 5000 - 000000002473.jpg
# ---> a skier jumping in the air
# 30 out of 5000 - 000000002532.jpg
# ---> a person on skis on a snowy mountain
# 31 out of 5000 - 000000002587.jpg
# ---> a banana and a donut in a bag
# 32 out of 5000 - 000000002592.jpg
# ---> a knife next to a mug
# 33 out of 5000 - 000000002685.jpg
# ---> a group of people standing around a counter
# 34 out of 5000 - 000000002923.jpg
# ---> birds in a field
# 35 out of 5000 - 000000003156.jpg
# ---> a man in gloves on a toilet
# 36 out of 5000 - 000000003255.jpg
# ---> a group of people standing on a snowy mountain
# 37 out of 5000 - 000000003501.jpg
# ---> a bowl of rice and broccoli
# 38 out of 5000 - 000000003553.jpg
# ---> a person riding a skateboard
# 39 out of 5000 - 000000003661.jpg
# ---> a bunch of bananas on a table
# 40 out of 5000 - 000000003845.jpg
# ---> a plate of food on a table
# 41 out of 5000 - 000000003934.jpg
# ---> a girl playing video game with a woman and a man
# 42 out of 5000 - 000000004134.jpg
# ---> a man shaking hands with another man
# 43 out of 5000 - 000000004395.jpg
# ---> a man in a tie
# 44 out of 5000 - 000000004495.jpg
# ---> a room with couches and tv
# 45 out of 5000 - 000000004765.jpg
# ---> a man surfing on a wave
# 46 out of 5000 - 000000004795.jpg
# ---> a cat looking at a computer screen
# 47 out of 5000 - 000000005001.jpg
# ---> a group of people cutting a ribbon
# 48 out of 5000 - 000000005037.jpg
# ---> a bus on the street
# 49 out of 5000 - 000000005060.jpg
# ---> a man taking a selfie in a mirror
# 50 out of 5000 - 000000005193.jpg
# ---> a group of people posing with surfboards
# 51 out of 5000 - 000000005477.jpg
# ---> a large airplane on a runway
# 52 out of 5000 - 000000005503.jpg
# ---> a toilet with a seat up
# 53 out of 5000 - 000000005529.jpg
# ---> a person skiing down a slope
# 54 out of 5000 - 000000005586.jpg
# ---> a tennis player serving a ball
# 55 out of 5000 - 000000005600.jpg
# ---> a bowl of food on a plate
# 56 out of 5000 - 000000005992.jpg
# ---> a group of sheep standing in grass
# 57 out of 5000 - 000000006012.jpg
# ---> a bunch of bananas with a red apple
# 58 out of 5000 - 000000006040.jpg
# ---> a train on the road
# 59 out of 5000 - 000000006213.jpg
# ---> a bathroom with a red shower curtain
# 60 out of 5000 - 000000006460.jpg
# ---> a person is surfing on the waves
# 61 out of 5000 - 000000006471.jpg
# ---> a baseball player holding a bat
# 62 out of 5000 - 000000006614.jpg
# ---> a group of fruits and peanuts
# 63 out of 5000 - 000000006723.jpg
# ---> a road with cars on it
# 64 out of 5000 - 000000006763.jpg
# ---> a man and woman posing for a picture
# 65 out of 5000 - 000000006771.jpg
# ---> a woman in a garment talking on a cell phone
# 66 out of 5000 - 000000006818.jpg
# ---> a toilet in a bathroom
# 67 out of 5000 - 000000006894.jpg
# ---> a man touching an elephant's trunk
# 68 out of 5000 - 000000006954.jpg
# ---> a group of children sitting in the grass
# 69 out of 5000 - 000000007088.jpg
# ---> a little girl holding an umbrella
# 70 out of 5000 - 000000007108.jpg
# ---> a baby elephant walking in the dirt
# 71 out of 5000 - 000000007278.jpg
# ---> a man surfing on a wave
# 72 out of 5000 - 000000007281.jpg
# ---> two men riding horses on a beach
# 73 out of 5000 - 000000007386.jpg
# ---> a motorcycle with a trailer in the back
# 74 out of 5000 - 000000007511.jpg
# ---> a man flying a kite on a beach
# 75 out of 5000 - 000000007574.jpg
# ---> a kitchen with a sink and a dishwasher
# 76 out of 5000 - 000000007784.jpg
# ---> a red and white kite in the air
# 77 out of 5000 - 000000007795.jpg
# ---> a room with two beds and a window
# 78 out of 5000 - 000000007816.jpg
# ---> a man riding a motorcycle
# 79 out of 5000 - 000000007818.jpg
# ---> a vase of flowers on a table
# 80 out of 5000 - 000000007888.jpg
# ---> a clock tower with a square face
# 81 out of 5000 - 000000007977.jpg
# ---> a man riding a skateboard
# 82 out of 5000 - 000000007991.jpg
# ---> a plate of carrots and beans
# 83 out of 5000 - 000000008021.jpg
# ---> a man on a screen
# 84 out of 5000 - 000000008211.jpg
# ---> a man sitting on a chair next to a scooter
# 85 out of 5000 - 000000008277.jpg
# ---> a plate of chicken and broccoli soup
# 86 out of 5000 - 000000008532.jpg
# ---> a man wearing a hat and glasses
# 87 out of 5000 - 000000008629.jpg
# ---> a pizza on a plate
# 88 out of 5000 - 000000008690.jpg
# ---> a group of girls petting goats
# 89 out of 5000 - 000000008762.jpg
# ---> a street light is green
# 90 out of 5000 - 000000008844.jpg
# ---> a woman smiling at a table with bananas
# 91 out of 5000 - 000000008899.jpg
# ---> a fire hydrant next to a building
# 92 out of 5000 - 000000009378.jpg
# ---> a man with long hair and a yellow frisbee
# 93 out of 5000 - 000000009400.jpg
# ---> people sitting at a table with laptops
# 94 out of 5000 - 000000009448.jpg
# ---> a girl holding a blue umbrella
# 95 out of 5000 - 000000009483.jpg
# ---> a man standing in front of a computer
# 96 out of 5000 - 000000009590.jpg
# ---> a group of people sitting around a table eating
# 97 out of 5000 - 000000009769.jpg
# ---> a red truck with a snow plow on the front of it
# 98 out of 5000 - 000000009772.jpg
# ---> a person taking a picture of a bathroom
# 99 out of 5000 - 000000009891.jpg
# ---> a man loading luggage into a car
# 100 out of 5000 - 000000009914.jpg
# ---> a plate of food with a sandwich and fries
# 101 out of 5000 - 000000010092.jpg
# ---> a bed with a mosquito net
# 102 out of 5000 - 000000010363.jpg
# ---> a cat standing on a car hood
# 103 out of 5000 - 000000010583.jpg
# ---> a plate of food with gravy
# 104 out of 5000 - 000000010707.jpg
# ---> a group of people playing video games
# 105 out of 5000 - 000000010764.jpg
# ---> a baseball player squatting on the ground
# 106 out of 5000 - 000000010977.jpg
# ---> a bathroom with pink tile walls and toilet
# 107 out of 5000 - 000000010995.jpg
# ---> a bed with a plaid blanket
# 108 out of 5000 - 000000011051.jpg
# ---> a man and woman smiling
# 109 out of 5000 - 000000011122.jpg
# ---> a stop sign behind a fence
# 110 out of 5000 - 000000011149.jpg
# ---> a group of bicycles parked on a road
# 111 out of 5000 - 000000011197.jpg
# ---> a couple of men standing on a sidewalk
# 112 out of 5000 - 000000011511.jpg
# ---> a statue of two women sitting on a bench
# 113 out of 5000 - 000000011615.jpg
# ---> a sign board with different directions
# 114 out of 5000 - 000000011699.jpg
# ---> a woman and a girl standing next to each other with luggage
# 115 out of 5000 - 000000011760.jpg
# ---> zebras walking in a zoo exhibit
# 116 out of 5000 - 000000011813.jpg
# ---> a camera on a tripod
# 117 out of 5000 - 000000012062.jpg
# ---> a sheep in a cage
# 118 out of 5000 - 000000012120.jpg
# ---> a tennis player is playing a game
# 119 out of 5000 - 000000012280.jpg
# ---> a man with a hat and a suitcase
# 120 out of 5000 - 000000012576.jpg
# ---> a pizza in boxes on a table
# 121 out of 5000 - 000000012639.jpg
# ---> a boy holding a baseball bat
# 122 out of 5000 - 000000012667.jpg
# ---> a banana on a telephone
# 123 out of 5000 - 000000012670.jpg
# ---> a group of people standing in a crowd
# 124 out of 5000 - 000000012748.jpg
# ---> a man holding a baby next to a horse
# 125 out of 5000 - 000000013004.jpg
# ---> a banana and peanut butter on a plate
# 126 out of 5000 - 000000013177.jpg
# ---> a man working on a tire
# 127 out of 5000 - 000000013201.jpg
# ---> a man doing a trick on a skateboard
# 128 out of 5000 - 000000013291.jpg
# ---> a group of people holding frisbees
# 129 out of 5000 - 000000013348.jpg
# ---> a large airplane parked on a runway
# 130 out of 5000 - 000000013546.jpg
# ---> a man riding a skateboard on a ramp
# 131 out of 5000 - 000000013597.jpg
# ---> a piece of chocolate cake on a plate
# 132 out of 5000 - 000000013659.jpg
# ---> a group of people working on laptops
# 133 out of 5000 - 000000013729.jpg
# ---> a group of people playing video games
# 134 out of 5000 - 000000013774.jpg
# ---> a person standing on a beach with a frisbee in the air
# 135 out of 5000 - 000000013923.jpg
# ---> a living room with a white couch and red chairs
# 136 out of 5000 - 000000014007.jpg
# ---> a cat sitting on top of a refrigerator
# 137 out of 5000 - 000000014038.jpg
# ---> a room with balloons and a table
# 138 out of 5000 - 000000014226.jpg
# ---> a man using a laptop on a train
# 139 out of 5000 - 000000014380.jpg
# ---> a train on the tracks
# 140 out of 5000 - 000000014439.jpg
# ---> a woman holding a kite
# 141 out of 5000 - 000000014473.jpg
# ---> a toy train on the tracks
# 142 out of 5000 - 000000014831.jpg
# ---> a close up of a cat's fur
# 143 out of 5000 - 000000014888.jpg
# ---> a cow milking machine
# 144 out of 5000 - 000000015079.jpg
# ---> a sandwich on a plate
# 145 out of 5000 - 000000015254.jpg
# ---> a tray of food with different types of food
# 146 out of 5000 - 000000015272.jpg
# ---> a traffic light under a tree
# 147 out of 5000 - 000000015278.jpg
# ---> a plate of broccoli and chicken
# 148 out of 5000 - 000000015335.jpg
# ---> a group of people sitting at a table
# 149 out of 5000 - 000000015338.jpg
# ---> buses on the street
# 150 out of 5000 - 000000015440.jpg
# ---> a stop sign on a pole
# 151 out of 5000 - 000000015497.jpg
# ---> a cat lying on a couch with a computer mouse
# 152 out of 5000 - 000000015517.jpg
# ---> a group of buses on a street
# 153 out of 5000 - 000000015597.jpg
# ---> a man in a cowboy hat skating on a ramp
# 154 out of 5000 - 000000015660.jpg
# ---> a person on a surfboard in the ocean
# 155 out of 5000 - 000000015746.jpg
# ---> a red fire hydrant in the grass
# 156 out of 5000 - 000000015751.jpg
# ---> a bird flying over a blue roof
# 157 out of 5000 - 000000015956.jpg
# ---> a woman walking a horse in a barn
# 158 out of 5000 - 000000016010.jpg
# ---> zebras and buffalo in a zoo exhibit
# 159 out of 5000 - 000000016228.jpg
# ---> a horse pulling a trolley
# 160 out of 5000 - 000000016249.jpg
# ---> a group of men sitting on benches
# 161 out of 5000 - 000000016439.jpg
# ---> a laptop on a desk
# 162 out of 5000 - 000000016451.jpg
# ---> surf surfboards and towels on a beach
# 163 out of 5000 - 000000016502.jpg
# ---> a sheep standing on a rock
# 164 out of 5000 - 000000016598.jpg
# ---> a woman taking a selfie
# 165 out of 5000 - 000000016958.jpg
# ---> a room with a fireplace and a bookcase
# 166 out of 5000 - 000000017029.jpg
# ---> a dog jumping in the air to catch a frisbee
# 167 out of 5000 - 000000017031.jpg
# ---> a giraffe looking at the camera
# 168 out of 5000 - 000000017115.jpg
# ---> zebras standing in front of a fence
# 169 out of 5000 - 000000017178.jpg
# ---> a group of horses stand on the side of the road
# 170 out of 5000 - 000000017182.jpg
# ---> a desk with books and an apple on it
# 171 out of 5000 - 000000017207.jpg
# ---> a bus on the road
# 172 out of 5000 - 000000017379.jpg
# ---> a tv in a bathroom
# 173 out of 5000 - 000000017436.jpg
# ---> a man sitting on a bench
# 174 out of 5000 - 000000017627.jpg
# ---> cars parked on the street
# 175 out of 5000 - 000000017714.jpg
# ---> a plate of food and a cup of tea on a table
# 176 out of 5000 - 000000017899.jpg
# ---> a woman putting food into a pan
# 177 out of 5000 - 000000017905.jpg
# ---> a man standing next to a traffic light
# 178 out of 5000 - 000000017959.jpg
# ---> kites flying in the air at a park
# 179 out of 5000 - 000000018150.jpg
# ---> a man and child eating pizza
# 180 out of 5000 - 000000018193.jpg
# ---> a woman eating a hot dog
# 181 out of 5000 - 000000018380.jpg
# ---> a group of people around a table with food
# 182 out of 5000 - 000000018491.jpg
# ---> a baseball player sliding into base
# 183 out of 5000 - 000000018519.jpg
# ---> a man in black riding a skateboard
# 184 out of 5000 - 000000018575.jpg
# ---> a plate of food with a sandwich and fries
# 185 out of 5000 - 000000018737.jpg
# ---> a motorcycle parked on the side of the road
# 186 out of 5000 - 000000018770.jpg
# ---> a man in a suit and tie
# 187 out of 5000 - 000000018833.jpg
# ---> a cat sleeping on a pair of shoes
# 188 out of 5000 - 000000018837.jpg
# ---> a green truck with a couple of men on top
# 189 out of 5000 - 000000019042.jpg
# ---> a bird standing on rocks in a river
# 190 out of 5000 - 000000019109.jpg
# ---> a row of motorcycles parked on the side of a street
# 191 out of 5000 - 000000019221.jpg
# ---> a person holding a piece of broccoli
# 192 out of 5000 - 000000019402.jpg
# ---> a man and woman in winter clothes
# 193 out of 5000 - 000000019432.jpg
# ---> a man playing tennis on a court
# 194 out of 5000 - 000000019742.jpg
# ---> a glass vase with a picture on it
# 195 out of 5000 - 000000019786.jpg
# ---> a man standing next to a man
# 196 out of 5000 - 000000019924.jpg
# ---> a woman wearing a hat and smoking a cigarette
# 197 out of 5000 - 000000020059.jpg
# ---> zebras grazing on grass in a zoo exhibit
# 198 out of 5000 - 000000020107.jpg
# ---> a fire hydrant on the sidewalk
# 199 out of 5000 - 000000020247.jpg
# ---> a bear walking on a dirt road
# 200 out of 5000 - 000000020333.jpg
# ---> a child playing with a water bowl
# 201 out of 5000 - 000000020553.jpg
# ---> a stuffed animal on a chair in a desert
# 202 out of 5000 - 000000020571.jpg
# ---> boats on the water
# 203 out of 5000 - 000000020992.jpg
# ---> a woman eating a hot dog
# 204 out of 5000 - 000000021167.jpg
# ---> a man and woman in formal attire
# 205 out of 5000 - 000000021465.jpg
# ---> a blue shelf with a vase and other objects on it
# 206 out of 5000 - 000000021503.jpg
# ---> a plate of crackers with butter
# 207 out of 5000 - 000000021604.jpg
# ---> a man in a suit with lights on his tie
# 208 out of 5000 - 000000021839.jpg
# ---> a man playing guitar on a street
# 209 out of 5000 - 000000021879.jpg
# ---> a girl surfing on a surfboard
# 210 out of 5000 - 000000021903.jpg
# ---> a man touching an elephant's trunk
# 211 out of 5000 - 000000022192.jpg
# ---> a dog sitting on a bed
# 212 out of 5000 - 000000022371.jpg
# ---> a man sitting at a desk with a laptop and a pen
# 213 out of 5000 - 000000022396.jpg
# ---> an airplane flying in the sky
# 214 out of 5000 - 000000022479.jpg
# ---> a man jumping on a skateboard
# 215 out of 5000 - 000000022589.jpg
# ---> sheep in a fenced area
# 216 out of 5000 - 000000022623.jpg
# ---> close-up of a music player
# 217 out of 5000 - 000000022705.jpg
# ---> a woman in a black dress holding a drink
# 218 out of 5000 - 000000022755.jpg
# ---> a rear view mirror of a school bus
# 219 out of 5000 - 000000022892.jpg
# ---> a cat and dog looking at a potted plant
# 220 out of 5000 - 000000022935.jpg
# ---> a woman in a blue uniform running with a ball
# 221 out of 5000 - 000000022969.jpg
# ---> giraffes in a zoo exhibit
# 222 out of 5000 - 000000023023.jpg
# ---> luggage in a room next to a bag
# 223 out of 5000 - 000000023034.jpg
# ---> a man looking at a group of horses on a trail
# 224 out of 5000 - 000000023126.jpg
# ---> a man riding a horse
# 225 out of 5000 - 000000023230.jpg
# ---> a group of geese swimming in a lake
# 226 out of 5000 - 000000023272.jpg
# ---> a cat sitting on the hood of a car
# 227 out of 5000 - 000000023359.jpg
# ---> a man jumping on a snowboard
# 228 out of 5000 - 000000023666.jpg
# ---> a toilet and bathtub in a bathroom
# 229 out of 5000 - 000000023751.jpg
# ---> a statue of two girls holding a kite
# 230 out of 5000 - 000000023781.jpg
# ---> a group of vegetables are on a table
# 231 out of 5000 - 000000023899.jpg
# ---> a group of people sitting on a couch playing video games
# 232 out of 5000 - 000000023937.jpg
# ---> a cow lying in the grass
# 233 out of 5000 - 000000024021.jpg
# ---> a group of people posing for a photo
# 234 out of 5000 - 000000024027.jpg
# ---> a kite in the air
# 235 out of 5000 - 000000024144.jpg
# ---> a pizza in a box
# 236 out of 5000 - 000000024243.jpg
# ---> a woman sitting in a refrigerator
# 237 out of 5000 - 000000024567.jpg
# ---> a man holding a tray of hot dogs
# 238 out of 5000 - 000000024610.jpg
# ---> a room with a table and bookshelf
# 239 out of 5000 - 000000024919.jpg
# ---> two elephants in a field
# 240 out of 5000 - 000000025057.jpg
# ---> a man holding a frisbee
# 241 out of 5000 - 000000025096.jpg
# ---> a boy cutting a cake
# 242 out of 5000 - 000000025139.jpg
# ---> a close-up of a zebra's face
# 243 out of 5000 - 000000025181.jpg
# ---> a train at a train station
# 244 out of 5000 - 000000025228.jpg
# ---> a woman on a surfboard in the water
# 245 out of 5000 - 000000025386.jpg
# ---> a man and woman eating food on a train
# 246 out of 5000 - 000000025393.jpg
# ---> two men in suits walking on a street
# 247 out of 5000 - 000000025394.jpg
# ---> a man cleaning a wine bottle
# 248 out of 5000 - 000000025424.jpg
# ---> a man swinging a tennis racket
# 249 out of 5000 - 000000025560.jpg
# ---> a cat on a shelf
# 250 out of 5000 - 000000025593.jpg
# ---> a street sign with a bicycle and a person walking on it
# 251 out of 5000 - 000000025603.jpg
# ---> a girl sitting at a table with pizza
# 252 out of 5000 - 000000025986.jpg
# ---> a table with plates of food and a glass of water
# 253 out of 5000 - 000000026204.jpg
# ---> a bus and cars on a street
# 254 out of 5000 - 000000026465.jpg
# ---> a laptop on a table
# 255 out of 5000 - 000000026564.jpg
# ---> a computer and keyboard on a desk
# 256 out of 5000 - 000000026690.jpg
# ---> a man doing a trick on a skateboard
# 257 out of 5000 - 000000026926.jpg
# ---> a fire hydrant with a face painted on it
# 258 out of 5000 - 000000026941.jpg
# ---> a cart full of luggage
# 259 out of 5000 - 000000027186.jpg
# ---> a girl holding a video game controller
# 260 out of 5000 - 000000027620.jpg
# ---> a laptop on a glass desk
# 261 out of 5000 - 000000027696.jpg
# ---> a pizza with peppers and mushrooms on a plate
# 262 out of 5000 - 000000027768.jpg
# ---> a bus parked on the side of the road
# 263 out of 5000 - 000000027932.jpg
# ---> a baseball glove and mitt on the ground
# 264 out of 5000 - 000000027972.jpg
# ---> a man surfing in the ocean
# 265 out of 5000 - 000000027982.jpg
# ---> a bathroom with a sink and toilet
# 266 out of 5000 - 000000028285.jpg
# ---> a clock tower with a blue roof
# 267 out of 5000 - 000000028449.jpg
# ---> a group of elephants standing in a forest
# 268 out of 5000 - 000000028452.jpg
# ---> a refrigerator with shelves and a bottle of juice
# 269 out of 5000 - 000000028809.jpg
# ---> a bunch of bananas on a shelf
# 270 out of 5000 - 000000028993.jpg
# ---> a row of fire hydrants in a city
# 271 out of 5000 - 000000029187.jpg
# ---> a horse and jockey pulling a cart
# 272 out of 5000 - 000000029393.jpg
# ---> a dog standing on a bench
# 273 out of 5000 - 000000029397.jpg
# ---> a person standing on a bench
# 274 out of 5000 - 000000029596.jpg
# ---> a living room with a table and chairs
# 275 out of 5000 - 000000029640.jpg
# ---> a pan of food with a spoon
# 276 out of 5000 - 000000029675.jpg
# ---> a group of hot dogs with mustard on them
# 277 out of 5000 - 000000029984.jpg
# ---> a group of people swimming in the water
# 278 out of 5000 - 000000030213.jpg
# ---> a kitchen with old appliances
# 279 out of 5000 - 000000030494.jpg
# ---> a dog playing with a frisbee
# 280 out of 5000 - 000000030504.jpg
# ---> a person skiing down a snowy slope
# 281 out of 5000 - 000000030675.jpg
# ---> a train on the tracks
# 282 out of 5000 - 000000030785.jpg
# ---> a bowl of guacamole and bread on a plate
# 283 out of 5000 - 000000030828.jpg
# ---> a person sleeping on a bench
# 284 out of 5000 - 000000031050.jpg
# ---> a vase with dried flowers
# 285 out of 5000 - 000000031093.jpg
# ---> a man riding a skateboard at a skate park
# 286 out of 5000 - 000000031118.jpg
# ---> a clock tower with a christmas tree and people walking around
# 287 out of 5000 - 000000031217.jpg
# ---> a boy playing tennis on a court
# 288 out of 5000 - 000000031248.jpg
# ---> a room with a fireplace and a chair
# 289 out of 5000 - 000000031269.jpg
# ---> zebras grazing in a grassy field
# 290 out of 5000 - 000000031296.jpg
# ---> a group of people sitting at a table
# 291 out of 5000 - 000000031322.jpg
# ---> a group of swans in a lake
# 292 out of 5000 - 000000031620.jpg
# ---> a man and woman cutting a cake
# 293 out of 5000 - 000000031735.jpg
# ---> a living room with red walls and a couch
# 294 out of 5000 - 000000031749.jpg
# ---> a doll with a clock
# 295 out of 5000 - 000000031817.jpg
# ---> a man on a scooter
# 296 out of 5000 - 000000032038.jpg
# ---> a pizza being cut on a wood surface
# 297 out of 5000 - 000000032081.jpg
# ---> a woman serving a tennis ball
# 298 out of 5000 - 000000032285.jpg
# ---> a bathroom with a towel from the door
# 299 out of 5000 - 000000032334.jpg
# ---> a man and woman holding wine glasses
# 300 out of 5000 - 000000032570.jpg
# ---> a man surfing in a wave
# 301 out of 5000 - 000000032610.jpg
# ---> laptops and bags on a table
# 302 out of 5000 - 000000032735.jpg
# ---> a person in the air on skis
# 303 out of 5000 - 000000032811.jpg
# ---> a bird on a window
# 304 out of 5000 - 000000032817.jpg
# ---> a man cleaning a toilet
# 305 out of 5000 - 000000032861.jpg
# ---> a man standing in the rain holding an umbrella
# 306 out of 5000 - 000000032887.jpg
# ---> a man with a backpack and poles
# 307 out of 5000 - 000000032901.jpg
# ---> a group of men posing for a photo
# 308 out of 5000 - 000000032941.jpg
# ---> a traffic light on the street
# 309 out of 5000 - 000000033005.jpg
# ---> a man holding a tennis racket
# 310 out of 5000 - 000000033104.jpg
# ---> a group of people on skis shaking hands
# 311 out of 5000 - 000000033109.jpg
# ---> a blue truck on the street
# 312 out of 5000 - 000000033114.jpg
# ---> an airplane on the runway
# 313 out of 5000 - 000000033221.jpg
# ---> a group of people on a beach
# 314 out of 5000 - 000000033368.jpg
# ---> a man holding a tennis racket
# 315 out of 5000 - 000000033638.jpg
# ---> a woman standing in a kitchen
# 316 out of 5000 - 000000033707.jpg
# ---> giraffes standing in a zoo exhibit
# 317 out of 5000 - 000000033759.jpg
# ---> a boy swinging a baseball bat
# 318 out of 5000 - 000000033854.jpg
# ---> a group of people standing around motorcycles
# 319 out of 5000 - 000000034071.jpg
# ---> a parking meter in the sun
# 320 out of 5000 - 000000034139.jpg
# ---> a couple standing next to a large suitcase
# 321 out of 5000 - 000000034205.jpg
# ---> a plate of food with broccoli and mushrooms
# 322 out of 5000 - 000000034257.jpg
# ---> a group of vegetables in baskets
# 323 out of 5000 - 000000034417.jpg
# ---> a doughnut factory with many donuts
# 324 out of 5000 - 000000034452.jpg
# ---> a man throwing frisbee in the woods
# 325 out of 5000 - 000000034760.jpg
# ---> a bathroom with a sink and a shower
# 326 out of 5000 - 000000034873.jpg
# ---> a kitchen with a sink and a wooden island
# 327 out of 5000 - 000000035062.jpg
# ---> a bed with a blanket and a pillow
# 328 out of 5000 - 000000035197.jpg
# ---> a person riding a skateboard
# 329 out of 5000 - 000000035279.jpg
# ---> a laptop and other items on the floor
# 330 out of 5000 - 000000035326.jpg
# ---> a stove top with a black burner
# 331 out of 5000 - 000000035682.jpg
# ---> a man eating a donut
# 332 out of 5000 - 000000035770.jpg
# ---> a bathroom with a sink and toilet
# 333 out of 5000 - 000000035963.jpg
# ---> a statue of a person holding a teddy bear
# 334 out of 5000 - 000000036494.jpg
# ---> a large clock in a large room
# 335 out of 5000 - 000000036539.jpg
# ---> a man and child skiing on the snow
# 336 out of 5000 - 000000036660.jpg
# ---> a flip flops and a cell phone
# 337 out of 5000 - 000000036678.jpg
# ---> a large building with a clock tower and a boat in the water with Palace of Westminster in the background
# 338 out of 5000 - 000000036844.jpg
# ---> a living room with a fan and a couch
# 339 out of 5000 - 000000036861.jpg
# ---> a parking meter on the side of the road
# 340 out of 5000 - 000000036936.jpg
# ---> a man and woman playing video games
# 341 out of 5000 - 000000037670.jpg
# ---> a hand holding a remote control
# 342 out of 5000 - 000000037689.jpg
# ---> a person on a snowboard jumping over a ramp
# 343 out of 5000 - 000000037740.jpg
# ---> a desk with a computer and a lamp
# 344 out of 5000 - 000000037751.jpg
# ---> a person on a motorcycle on a dirt road
# 345 out of 5000 - 000000037777.jpg
# ---> a kitchen with a bowl of oranges
# 346 out of 5000 - 000000037988.jpg
# ---> a woman serving a tennis ball
# 347 out of 5000 - 000000038048.jpg
# ---> a red fire hydrant on a sidewalk
# 348 out of 5000 - 000000038070.jpg
# ---> a toilet in a small bathroom
# 349 out of 5000 - 000000038118.jpg
# ---> a person skiing down a snowy mountain
# 350 out of 5000 - 000000038210.jpg
# ---> a man skiing on the snow
# 351 out of 5000 - 000000038576.jpg
# ---> a computer monitor and keyboard on a desk
# 352 out of 5000 - 000000038678.jpg
# ---> a woman holding a bagel
# 353 out of 5000 - 000000038825.jpg
# ---> a couple of zebras grazing on grass
# 354 out of 5000 - 000000038829.jpg
# ---> a group of people riding a bicycle
# 355 out of 5000 - 000000039405.jpg
# ---> a tennis player hitting a ball with a racket
# 356 out of 5000 - 000000039477.jpg
# ---> a small living room with a couch and a sewing machine
# 357 out of 5000 - 000000039480.jpg
# ---> a woman holding a tennis racket
# 358 out of 5000 - 000000039484.jpg
# ---> a busy city street with cars and shops
# 359 out of 5000 - 000000039551.jpg
# ---> a woman playing tennis on a court
# 360 out of 5000 - 000000039670.jpg
# ---> a train going through the woods
# 361 out of 5000 - 000000039769.jpg
# ---> cats lying on a couch
# 362 out of 5000 - 000000039785.jpg
# ---> a man surfing in a river
# 363 out of 5000 - 000000039914.jpg
# ---> a woman and child flying a kite
# 364 out of 5000 - 000000039951.jpg
# ---> a boy swinging a tennis racket
# 365 out of 5000 - 000000039956.jpg
# ---> a bedroom with a bed and a pile of stuff
# 366 out of 5000 - 000000040036.jpg
# ---> a person on a horse jumping a fence
# 367 out of 5000 - 000000040083.jpg
# ---> a man sitting under an umbrella
# 368 out of 5000 - 000000040471.jpg
# ---> a kitchen with white cabinets and a chandelier
# 369 out of 5000 - 000000040757.jpg
# ---> a child lying on a bed with a pacifier
# 370 out of 5000 - 000000041488.jpg
# ---> a green sign with white text
# 371 out of 5000 - 000000041633.jpg
# ---> a red truck parked on a road
# 372 out of 5000 - 000000041635.jpg
# ---> cows standing behind a barbed wire fence
# 373 out of 5000 - 000000041872.jpg
# ---> a bedroom with a fireplace and a bed
# 374 out of 5000 - 000000041888.jpg
# ---> a group of birds in a field
# 375 out of 5000 - 000000041990.jpg
# ---> a group of people skiing on the snow
# 376 out of 5000 - 000000042070.jpg
# ---> a bus on the street
# 377 out of 5000 - 000000042102.jpg
# ---> a man in a school uniform
# 378 out of 5000 - 000000042178.jpg
# ---> a train station with many trains
# 379 out of 5000 - 000000042276.jpg
# ---> a toilet with shoes and gloves
# 380 out of 5000 - 000000042296.jpg
# ---> a polar bear playing with balls in water
# 381 out of 5000 - 000000042528.jpg
# ---> a person holding a flip phone
# 382 out of 5000 - 000000042563.jpg
# ---> a train on a snowy track
# 383 out of 5000 - 000000042628.jpg
# ---> a fire hydrant buried in snow
# 384 out of 5000 - 000000042888.jpg
# ---> a street sign on a pole
# 385 out of 5000 - 000000042889.jpg
# ---> a teddy bear wearing glasses and a cell phone
# 386 out of 5000 - 000000043314.jpg
# ---> a person skiing down a slope
# 387 out of 5000 - 000000043435.jpg
# ---> a group of people surfing in the ocean
# 388 out of 5000 - 000000043581.jpg
# ---> a pizza on a plate
# 389 out of 5000 - 000000043737.jpg
# ---> a clock on a pole in a city
# 390 out of 5000 - 000000043816.jpg
# ---> a baseball player swinging a bat
# 391 out of 5000 - 000000044068.jpg
# ---> a teddy bear sitting on a chair
# 392 out of 5000 - 000000044195.jpg
# ---> a man and woman holding snowboards on a snowy mountain
# 393 out of 5000 - 000000044260.jpg
# ---> a tree with apples on it
# 394 out of 5000 - 000000044279.jpg
# ---> a couple of men in a kitchen
# 395 out of 5000 - 000000044590.jpg
# ---> a group of motorcycles parked on the side of the road
# 396 out of 5000 - 000000044652.jpg
# ---> a plane flying in the sky
# 397 out of 5000 - 000000044699.jpg
# ---> a group of sheep on a hill
# 398 out of 5000 - 000000044877.jpg
# ---> a woman in wheelchair holding a tennis racket
# 399 out of 5000 - 000000045070.jpg
# ---> a girl riding a horse
# 400 out of 5000 - 000000045090.jpg
# ---> a group of surfers riding a wave
# 401 out of 5000 - 000000045229.jpg
# ---> a room with a window and a plant
# 402 out of 5000 - 000000045472.jpg
# ---> a pineapple and oranges next to a plate of oranges and a plate of red cups
# 403 out of 5000 - 000000045550.jpg
# ---> a man holding a plate of food
# 404 out of 5000 - 000000045596.jpg
# ---> a group of bicycles parked in front of a building
# 405 out of 5000 - 000000045728.jpg
# ---> a close up of food
# 406 out of 5000 - 000000046031.jpg
# ---> a laptop computer on a table
# 407 out of 5000 - 000000046048.jpg
# ---> a girl sitting on a bed
# 408 out of 5000 - 000000046252.jpg
# ---> a baseball player swinging his bat
# 409 out of 5000 - 000000046378.jpg
# ---> a cat eating a bird
# 410 out of 5000 - 000000046463.jpg
# ---> a sandwich with tomato and cheese
# 411 out of 5000 - 000000046497.jpg
# ---> a couple of girls on a boat
# 412 out of 5000 - 000000046804.jpg
# ---> a sheep standing in grass
# 413 out of 5000 - 000000046872.jpg
# ---> a man standing on a truck
# 414 out of 5000 - 000000047010.jpg
# ---> a group of giraffes walking in a zoo exhibit
# 415 out of 5000 - 000000047112.jpg
# ---> a pizza on a plate with glasses of beer
# 416 out of 5000 - 000000047121.jpg
# ---> a cat drinking water from a faucet
# 417 out of 5000 - 000000047571.jpg
# ---> a horse pulling a cart
# 418 out of 5000 - 000000047585.jpg
# ---> a man and woman holding an umbrella
# 419 out of 5000 - 000000047740.jpg
# ---> a man lying on the beach with colorful ribbons
# 420 out of 5000 - 000000047769.jpg
# ---> a living room with a tv and a table
# 421 out of 5000 - 000000047801.jpg
# ---> a man eating a piece of cake
# 422 out of 5000 - 000000047819.jpg
# ---> a man standing next to a donkey with luggage on it
# 423 out of 5000 - 000000047828.jpg
# ---> a bridge with lights on it
# 424 out of 5000 - 000000048153.jpg
# ---> a person's foot wearing pink shoes
# 425 out of 5000 - 000000048396.jpg
# ---> a woman holding a knife and a boy standing behind a table
# 426 out of 5000 - 000000048504.jpg
# ---> elephants in a circus arena
# 427 out of 5000 - 000000048555.jpg
# ---> a group of people riding horses on a beach
# 428 out of 5000 - 000000048564.jpg
# ---> a boy talking on a cell phone
# 429 out of 5000 - 000000048924.jpg
# ---> a motorcycle parked in a field
# 430 out of 5000 - 000000049060.jpg
# ---> a group of people standing next to a train
# 431 out of 5000 - 000000049091.jpg
# ---> signs on a street in a city
# 432 out of 5000 - 000000049259.jpg
# ---> a man lying on the side of a road
# 433 out of 5000 - 000000049269.jpg
# ---> a dog and horse standing in a field
# 434 out of 5000 - 000000049759.jpg
# ---> a group of people playing volleyball
# 435 out of 5000 - 000000049761.jpg
# ---> a group of zebras and a buffalo in a field
# 436 out of 5000 - 000000049810.jpg
# ---> a cat looking at a mirror
# 437 out of 5000 - 000000050006.jpg
# ---> boats docked boats on a lake
# 438 out of 5000 - 000000050145.jpg
# ---> a man with a towel on his neck and a bicycle
# 439 out of 5000 - 000000050149.jpg
# ---> bunch bunches of bananas from a ceiling
# 440 out of 5000 - 000000050165.jpg
# ---> a train on the tracks
# 441 out of 5000 - 000000050326.jpg
# ---> a man flying a kite on a beach
# 442 out of 5000 - 000000050331.jpg
# ---> a plant in a pot
# 443 out of 5000 - 000000050380.jpg
# ---> a man and child on a leash
# 444 out of 5000 - 000000050638.jpg
# ---> a child holding a stuffed animal
# 445 out of 5000 - 000000050679.jpg
# ---> an orange on the street
# 446 out of 5000 - 000000050811.jpg
# ---> a man sitting at a table with a bowl of food and bottles of beer
# 447 out of 5000 - 000000050828.jpg
# ---> a hotel room with a bed and a phone
# 448 out of 5000 - 000000050844.jpg
# ---> a group of stuffed animals
# 449 out of 5000 - 000000050896.jpg
# ---> a bowl of oranges
# 450 out of 5000 - 000000050943.jpg
# ---> a man surfing in the ocean with The Wedge in the background
# 451 out of 5000 - 000000051008.jpg
# ---> a cat sitting in front of a laptop
# 452 out of 5000 - 000000051309.jpg
# ---> a group of horses standing in a field
# 453 out of 5000 - 000000051314.jpg
# ---> a man surfing on the water
# 454 out of 5000 - 000000051326.jpg
# ---> a group of pumpkins with flowers
# 455 out of 5000 - 000000051598.jpg
# ---> a bathroom with a mirror and sink
# 456 out of 5000 - 000000051610.jpg
# ---> a baby sitting on a bed looking at a laptop
# 457 out of 5000 - 000000051712.jpg
# ---> a man skiing down a slope
# 458 out of 5000 - 000000051738.jpg
# ---> a hotel room with a bed and a chair
# 459 out of 5000 - 000000051938.jpg
# ---> a person on a red pipe
# 460 out of 5000 - 000000051961.jpg
# ---> a parking meter next to a wall with graffiti
# 461 out of 5000 - 000000051976.jpg
# ---> a person on a surfboard in the ocean
# 462 out of 5000 - 000000052007.jpg
# ---> a double decker bus on the street
# 463 out of 5000 - 000000052017.jpg
# ---> a yellow and red airplane flying in the sky
# 464 out of 5000 - 000000052412.jpg
# ---> an airplane wing and a parking lot with a large building and trees
# 465 out of 5000 - 000000052413.jpg
# ---> a person holding a flip phone
# 466 out of 5000 - 000000052462.jpg
# ---> zebras standing in tall grass
# 467 out of 5000 - 000000052507.jpg
# ---> a man holding a surfboard in the ocean
# 468 out of 5000 - 000000052565.jpg
# ---> a cow standing on the beach
# 469 out of 5000 - 000000052591.jpg
# ---> a woman holding skis and poles
# 470 out of 5000 - 000000052891.jpg
# ---> a dog holding a yellow frisbee on a beach
# 471 out of 5000 - 000000052996.jpg
# ---> a group of people in a kitchen
# 472 out of 5000 - 000000053505.jpg
# ---> a bathroom with a toilet and toilet
# 473 out of 5000 - 000000053529.jpg
# ---> a dog sitting in a truck
# 474 out of 5000 - 000000053624.jpg
# ---> an elephant standing in a pool of water
# 475 out of 5000 - 000000053626.jpg
# ---> a group of people posing for a picture on a snowy mountain
# 476 out of 5000 - 000000053909.jpg
# ---> a person holding a cell phone
# 477 out of 5000 - 000000053994.jpg
# ---> a parking meter on a sidewalk
# 478 out of 5000 - 000000054123.jpg
# ---> a group of zebras grazing in a field
# 479 out of 5000 - 000000054164.jpg
# ---> a man surfing on a wave
# 480 out of 5000 - 000000054592.jpg
# ---> a skiers with skis on a snowy mountain
# 481 out of 5000 - 000000054593.jpg
# ---> a boy holding a baseball bat
# 482 out of 5000 - 000000054605.jpg
# ---> a cake and a drink on a table
# 483 out of 5000 - 000000054628.jpg
# ---> a cake with a statue on top
# 484 out of 5000 - 000000054654.jpg
# ---> a woman in a sweater holding a plate of food
# 485 out of 5000 - 000000054931.jpg
# ---> a woman holding a rope next to a horse
# 486 out of 5000 - 000000054967.jpg
# ---> a traffic sign on a street
# 487 out of 5000 - 000000055002.jpg
# ---> a toilet with a metal lid
# 488 out of 5000 - 000000055022.jpg
# ---> a row of bicycles in a store
# 489 out of 5000 - 000000055072.jpg
# ---> a giraffe walking in a field
# 490 out of 5000 - 000000055150.jpg
# ---> a girl and boy sitting in a cart with luggage
# 491 out of 5000 - 000000055167.jpg
# ---> a bus on the road
# 492 out of 5000 - 000000055299.jpg
# ---> a bird on a rock by the water
# 493 out of 5000 - 000000055528.jpg
# ---> a man holding a toothbrush
# 494 out of 5000 - 000000055950.jpg
# ---> a man playing tennis on a court
# 495 out of 5000 - 000000056127.jpg
# ---> a kitchen with a sink and a fire extinguisher
# 496 out of 5000 - 000000056288.jpg
# ---> a sandwich with lettuce and meat
# 497 out of 5000 - 000000056344.jpg
# ---> a computer desk with a couple of monitors
# 498 out of 5000 - 000000056350.jpg
# ---> a bathroom with a urinal and a picture of people
# 499 out of 5000 - 000000056545.jpg
# ---> a bird on a branch
# 500 out of 5000 - 000000057027.jpg
# ---> a baby elephant under a baby elephant
# 501 out of 5000 - 000000057149.jpg
# ---> a car on the road
# 502 out of 5000 - 000000057150.jpg
# ---> a girl holding a stuffed bear
# 503 out of 5000 - 000000057232.jpg
# ---> a chair made of baseball bats and a book
# 504 out of 5000 - 000000057238.jpg
# ---> a white refrigerator in a kitchen
# 505 out of 5000 - 000000057244.jpg
# ---> a train on tracks with trees in the background
# 506 out of 5000 - 000000057597.jpg
# ---> a group of girls playing football
# 507 out of 5000 - 000000057672.jpg
# ---> a group of people rowing a boat
# 508 out of 5000 - 000000057725.jpg
# ---> a bridge over a river with a clock tower
# 509 out of 5000 - 000000057760.jpg
# ---> a group of people on a beach
# 510 out of 5000 - 000000058029.jpg
# ---> a bathroom with a mirror and sink
# 511 out of 5000 - 000000058111.jpg
# ---> a cat lying on a desk
# 512 out of 5000 - 000000058350.jpg
# ---> a woman eating pizza while another woman watches
# 513 out of 5000 - 000000058384.jpg
# ---> two elephants in a field
# 514 out of 5000 - 000000058393.jpg
# ---> a couple sitting on a bench overlooking the ocean
# 515 out of 5000 - 000000058539.jpg
# ---> a man wearing a suit and tie
# 516 out of 5000 - 000000058636.jpg
# ---> a street sign on a wooden pole
# 517 out of 5000 - 000000058655.jpg
# ---> a clock on a pole in front of a building
# 518 out of 5000 - 000000058705.jpg
# ---> a man and woman posing for a picture
# 519 out of 5000 - 000000059044.jpg
# ---> a group of people standing in a line
# 520 out of 5000 - 000000059386.jpg
# ---> giraffes standing around a tree
# 521 out of 5000 - 000000059598.jpg
# ---> a laptop and a banana on a plate
# 522 out of 5000 - 000000059635.jpg
# ---> a woman holding a surfboard
# 523 out of 5000 - 000000059920.jpg
# ---> a bathroom with a toilet and bidet
# 524 out of 5000 - 000000060052.jpg
# ---> a person holding an umbrella
# 525 out of 5000 - 000000060090.jpg
# ---> a train at a train station
# 526 out of 5000 - 000000060102.jpg
# ---> a group of men playing football
# 527 out of 5000 - 000000060347.jpg
# ---> a man sitting on a bench in the woods
# 528 out of 5000 - 000000060363.jpg
# ---> a clock on a building
# 529 out of 5000 - 000000060449.jpg
# ---> a laptop on a table
# 530 out of 5000 - 000000060507.jpg
# ---> a baseball player swinging a bat
# 531 out of 5000 - 000000060770.jpg
# ---> zebras standing in grass near a tree
# 532 out of 5000 - 000000060823.jpg
# ---> a group of birds and a cow
# 533 out of 5000 - 000000060835.jpg
# ---> a dog sitting in a cage
# 534 out of 5000 - 000000060855.jpg
# ---> a group of oranges and apples
# 535 out of 5000 - 000000060886.jpg
# ---> a baseball team huddle on a baseball field
# 536 out of 5000 - 000000060899.jpg
# ---> a child holding a brush
# 537 out of 5000 - 000000060932.jpg
# ---> a man in a white suit and tie holding a flower necklace
# 538 out of 5000 - 000000061108.jpg
# ---> a dog in a basket on a bicycle
# 539 out of 5000 - 000000061171.jpg
# ---> a group of cows eating hay
# 540 out of 5000 - 000000061268.jpg
# ---> a train going through a station
# 541 out of 5000 - 000000061333.jpg
# ---> a cat lying on a blanket
# 542 out of 5000 - 000000061418.jpg
# ---> a group of children playing checkers
# 543 out of 5000 - 000000061471.jpg
# ---> a dog playing with toilet paper
# 544 out of 5000 - 000000061584.jpg
# ---> a man and woman sitting on a statue
# 545 out of 5000 - 000000061658.jpg
# ---> a broccoli and cauliflower on a pan
# 546 out of 5000 - 000000061747.jpg
# ---> a woman on skis on a mountain
# 547 out of 5000 - 000000061960.jpg
# ---> a woman lying on a bed wearing black lingerie
# 548 out of 5000 - 000000062025.jpg
# ---> a bathroom with a sink and a toilet
# 549 out of 5000 - 000000062353.jpg
# ---> giraffes in a zoo exhibit
# 550 out of 5000 - 000000062355.jpg
# ---> a baseball player on a field
# 551 out of 5000 - 000000062554.jpg
# ---> a plate of food on a table
# 552 out of 5000 - 000000062692.jpg
# ---> a woman playing tennis on a court
# 553 out of 5000 - 000000062808.jpg
# ---> a man taking a picture of a pizza
# 554 out of 5000 - 000000063047.jpg
# ---> a man holding a paper bag
# 555 out of 5000 - 000000063154.jpg
# ---> a man lying on a surfboard in the ocean
# 556 out of 5000 - 000000063552.jpg
# ---> a cat looking through a circular mirror
# 557 out of 5000 - 000000063602.jpg
# ---> a laptop on a desk
# 558 out of 5000 - 000000063740.jpg
# ---> a laptop and keyboard on a desk
# 559 out of 5000 - 000000063965.jpg
# ---> a person holding a plate of cake
# 560 out of 5000 - 000000064084.jpg
# ---> a plate of bread and a bowl of salad
# 561 out of 5000 - 000000064359.jpg
# ---> a group of zebras and giraffes in a zoo exhibit
# 562 out of 5000 - 000000064462.jpg
# ---> a woman on skis on a snowy slope
# 563 out of 5000 - 000000064495.jpg
# ---> a parking meter on a pole
# 564 out of 5000 - 000000064499.jpg
# ---> zebras standing next to a wall
# 565 out of 5000 - 000000064523.jpg
# ---> a group of women holding tennis rackets
# 566 out of 5000 - 000000064574.jpg
# ---> a hairbrush and a flashlight on a white surface
# 567 out of 5000 - 000000064718.jpg
# ---> a man swinging a tennis racket
# 568 out of 5000 - 000000064868.jpg
# ---> a man holding a dog in the oven
# 569 out of 5000 - 000000064898.jpg
# ---> a couple of kids on surfboards in the ocean
# 570 out of 5000 - 000000065074.jpg
# ---> a bed with a wooden headboard and a wooden bed
# 571 out of 5000 - 000000065288.jpg
# ---> a group of people sitting outside
# 572 out of 5000 - 000000065350.jpg
# ---> a person is doing a trick on a skateboard
# 573 out of 5000 - 000000065455.jpg
# ---> a group of people feeding giraffes
# 574 out of 5000 - 000000065485.jpg
# ---> a dog sitting in the back of a car
# 575 out of 5000 - 000000065736.jpg
# ---> a woman swinging a tennis racket
# 576 out of 5000 - 000000065798.jpg
# ---> a baseball player swinging a bat at a baseball game
# 577 out of 5000 - 000000066038.jpg
# ---> a group of people sitting under umbrellas on a beach
# 578 out of 5000 - 000000066135.jpg
# ---> a yellow train at a train station
# 579 out of 5000 - 000000066231.jpg
# ---> a group of chefs in a kitchen
# 580 out of 5000 - 000000066523.jpg
# ---> a bed with a canopy over it
# 581 out of 5000 - 000000066561.jpg
# ---> a black and white sheep in a field
# 582 out of 5000 - 000000066635.jpg
# ---> a computer on a desk
# 583 out of 5000 - 000000066706.jpg
# ---> a plate of bread with bananas and a cup of coffee
# 584 out of 5000 - 000000066771.jpg
# ---> a man and woman looking at a phone
# 585 out of 5000 - 000000066817.jpg
# ---> a plate of food with a bowl of yogurt and a bowl of vegetables
# 586 out of 5000 - 000000066841.jpg
# ---> a toaster with a face made of spoons
# 587 out of 5000 - 000000066886.jpg
# ---> a child holding a pink hair brush
# 588 out of 5000 - 000000066926.jpg
# ---> a group of glazed donuts
# 589 out of 5000 - 000000067180.jpg
# ---> a woman sitting on a bench
# 590 out of 5000 - 000000067213.jpg
# ---> a dog jumping into a pool
# 591 out of 5000 - 000000067310.jpg
# ---> a man riding a skateboard
# 592 out of 5000 - 000000067315.jpg
# ---> a man wearing a tie
# 593 out of 5000 - 000000067406.jpg
# ---> a group of people flying a kite
# 594 out of 5000 - 000000067534.jpg
# ---> a man wearing a blue and black tie
# 595 out of 5000 - 000000067616.jpg
# ---> a group of people sitting at tables outside a restaurant
# 596 out of 5000 - 000000067896.jpg
# ---> a clock on a building
# 597 out of 5000 - 000000068078.jpg
# ---> a bathroom with orange shower curtain
# 598 out of 5000 - 000000068093.jpg
# ---> a man and woman sitting on a motorcycle
# 599 out of 5000 - 000000068286.jpg
# ---> a bed with white sheets and pillows
# 600 out of 5000 - 000000068387.jpg
# ---> a baseball player swinging a bat
# 601 out of 5000 - 000000068409.jpg
# ---> a group of boys sitting on the ground
# 602 out of 5000 - 000000068628.jpg
# ---> a man jumping on a skateboard
# 603 out of 5000 - 000000068765.jpg
# ---> a keyboard and mouse on a desk
# 604 out of 5000 - 000000068833.jpg
# ---> a kitchen with wood cabinets and a red carpet
# 605 out of 5000 - 000000068933.jpg
# ---> a group of zebras grazing
# 606 out of 5000 - 000000069106.jpg
# ---> zebras standing in a row
# 607 out of 5000 - 000000069138.jpg
# ---> a traffic light with a sad face on it
# 608 out of 5000 - 000000069213.jpg
# ---> two men in suits and hats
# 609 out of 5000 - 000000069224.jpg
# ---> a man and woman eating donuts
# 610 out of 5000 - 000000069356.jpg
# ---> a man and woman standing next to fruit stand
# 611 out of 5000 - 000000069795.jpg
# ---> a purple flowers in a watering can
# 612 out of 5000 - 000000070048.jpg
# ---> a sandwich and a salad on a tray
# 613 out of 5000 - 000000070158.jpg
# ---> a group of zebras walking on the ground
# 614 out of 5000 - 000000070229.jpg
# ---> a stuffed animal on a bench
# 615 out of 5000 - 000000070254.jpg
# ---> a train on the tracks
# 616 out of 5000 - 000000070739.jpg
# ---> a couple of women drinking wine
# 617 out of 5000 - 000000070774.jpg
# ---> a motorcycle with many bicycles on the back
# 618 out of 5000 - 000000071226.jpg
# ---> a dog and cat lying on a bed
# 619 out of 5000 - 000000071451.jpg
# ---> a bed with white sheets and towels
# 620 out of 5000 - 000000071711.jpg
# ---> a group of people walking in a hangar
# 621 out of 5000 - 000000071756.jpg
# ---> a couple of bears walking on the ground
# 622 out of 5000 - 000000071877.jpg
# ---> a person jumping on a skateboard
# 623 out of 5000 - 000000071938.jpg
# ---> a man sleeping with a cell phone to his ear
# 624 out of 5000 - 000000072281.jpg
# ---> a man doing a trick on a skateboard
# 625 out of 5000 - 000000072795.jpg
# ---> a baseball player on the field
# 626 out of 5000 - 000000072813.jpg
# ---> a dog lying on a bed
# 627 out of 5000 - 000000072852.jpg
# ---> a bicycle parked on the sidewalk
# 628 out of 5000 - 000000073118.jpg
# ---> two teddy bears in a box
# 629 out of 5000 - 000000073153.jpg
# ---> a man talking on a cell phone
# 630 out of 5000 - 000000073326.jpg
# ---> a refrigerator with food in it
# 631 out of 5000 - 000000073533.jpg
# ---> boys sitting on a bench looking at their phones
# 632 out of 5000 - 000000073702.jpg
# ---> a man walking with a colorful umbrella on his head
# 633 out of 5000 - 000000073946.jpg
# ---> a group of men holding a surfboard
# 634 out of 5000 - 000000074058.jpg
# ---> a man sitting at a table with umbrellas
# 635 out of 5000 - 000000074092.jpg
# ---> a woman playing tennis on a court
# 636 out of 5000 - 000000074200.jpg
# ---> surfboards in a window
# 637 out of 5000 - 000000074209.jpg
# ---> a kitchen with black and white furniture
# 638 out of 5000 - 000000074256.jpg
# ---> a woman standing next to another woman
# 639 out of 5000 - 000000074457.jpg
# ---> a person holding a surfboard on a beach
# 640 out of 5000 - 000000074646.jpg
# ---> a group of people flying a kite on a beach
# 641 out of 5000 - 000000074733.jpg
# ---> a pizza and beer on a table
# 642 out of 5000 - 000000074860.jpg
# ---> a man sitting on a snowboard
# 643 out of 5000 - 000000075393.jpg
# ---> a wooden forks on display
# 644 out of 5000 - 000000075456.jpg
# ---> a pizza in a pan
# 645 out of 5000 - 000000075612.jpg
# ---> a group of people playing video games
# 646 out of 5000 - 000000076211.jpg
# ---> a building with a clock on the front
# 647 out of 5000 - 000000076261.jpg
# ---> birds flying in the sky
# 648 out of 5000 - 000000076416.jpg
# ---> a double decker bus with a ipod logo on it
# 649 out of 5000 - 000000076417.jpg
# ---> a dog looking out of a car window
# 650 out of 5000 - 000000076468.jpg
# ---> two women on a tennis court shaking hands
# 651 out of 5000 - 000000076547.jpg
# ---> a man sitting at a table with a laptop
# 652 out of 5000 - 000000076625.jpg
# ---> a train on the tracks
# 653 out of 5000 - 000000076731.jpg
# ---> a pen on a blue case
# 654 out of 5000 - 000000077396.jpg
# ---> cats playing on a television
# 655 out of 5000 - 000000077460.jpg
# ---> a group of people flying kites in the sky
# 656 out of 5000 - 000000077595.jpg
# ---> a cat lying on a blanket next to a laptop
# 657 out of 5000 - 000000078032.jpg
# ---> a bench on a patio
# 658 out of 5000 - 000000078170.jpg
# ---> a woman sitting in a train
# 659 out of 5000 - 000000078266.jpg
# ---> a kitchen with stainless steel appliances
# 660 out of 5000 - 000000078404.jpg
# ---> a group of women sitting on a bench
# 661 out of 5000 - 000000078420.jpg
# ---> a cat laying on a laptop
# 662 out of 5000 - 000000078426.jpg
# ---> a cat sitting on a desk
# 663 out of 5000 - 000000078565.jpg
# ---> a group of people and a dog on a beach with sailboats
# 664 out of 5000 - 000000078748.jpg
# ---> motorcycles parked on the street
# 665 out of 5000 - 000000078823.jpg
# ---> a dog sitting on the back of a car
# 666 out of 5000 - 000000078843.jpg
# ---> a man and woman smiling
# 667 out of 5000 - 000000078915.jpg
# ---> a tennis player hitting a ball with a racket
# 668 out of 5000 - 000000078959.jpg
# ---> a banana tree with a flower
# 669 out of 5000 - 000000079014.jpg
# ---> a man looking through a window
# 670 out of 5000 - 000000079031.jpg
# ---> a boy on a surfboard
# 671 out of 5000 - 000000079034.jpg
# ---> a blue fire hydrant in a park
# 672 out of 5000 - 000000079144.jpg
# ---> a bear cubs playing on a log
# 673 out of 5000 - 000000079188.jpg
# ---> a giraffes sitting in a field
# 674 out of 5000 - 000000079229.jpg
# ---> a man riding a horse with a dog
# 675 out of 5000 - 000000079408.jpg
# ---> a stop sign with a branch on it
# 676 out of 5000 - 000000079565.jpg
# ---> a couple of giraffes standing in a field
# 677 out of 5000 - 000000079588.jpg
# ---> a large brick building with a clock with Hampton Court Palace in the background
# 678 out of 5000 - 000000079651.jpg
# ---> a banana next to bottles of beer
# 679 out of 5000 - 000000079837.jpg
# ---> a group of boats in a harbor
# 680 out of 5000 - 000000079969.jpg
# ---> a man playing tennis in a stadium
# 681 out of 5000 - 000000080022.jpg
# ---> a man playing tennis on a court
# 682 out of 5000 - 000000080057.jpg
# ---> a teddy bear playing with a toy
# 683 out of 5000 - 000000080153.jpg
# ---> a man and dog on skis
# 684 out of 5000 - 000000080273.jpg
# ---> a man snowboarding down a snowy hill
# 685 out of 5000 - 000000080274.jpg
# ---> elephants standing next to each other
# 686 out of 5000 - 000000080340.jpg
# ---> a child with a suitcase
# 687 out of 5000 - 000000080413.jpg
# ---> a stuffed bear in a car
# 688 out of 5000 - 000000080659.jpg
# ---> a group of jockeys riding horses
# 689 out of 5000 - 000000080666.jpg
# ---> a cat sitting on a bench
# 690 out of 5000 - 000000080671.jpg
# ---> a person skiing down a slope
# 691 out of 5000 - 000000080932.jpg
# ---> a child eating pizza at a restaurant
# 692 out of 5000 - 000000080949.jpg
# ---> a cat laying on a laptop
# 693 out of 5000 - 000000081061.jpg
# ---> a couch and a suitcase on the grass
# 694 out of 5000 - 000000081394.jpg
# ---> a truck on the street
# 695 out of 5000 - 000000081594.jpg
# ---> a woman holding an umbrella
# 696 out of 5000 - 000000081738.jpg
# ---> a person cutting a cake
# 697 out of 5000 - 000000081766.jpg
# ---> a group of dogs sitting on stairs
# 698 out of 5000 - 000000081988.jpg
# ---> a group of people in wet suits on the beach
# 699 out of 5000 - 000000082085.jpg
# ---> a train on the tracks
# 700 out of 5000 - 000000082180.jpg
# ---> two stuffed animals on a chair
# 701 out of 5000 - 000000082688.jpg
# ---> a man and woman playing video games
# 702 out of 5000 - 000000082696.jpg
# ---> a bird walking in a restaurant
# 703 out of 5000 - 000000082715.jpg
# ---> a man surfing on a wave
# 704 out of 5000 - 000000082765.jpg
# ---> a laptop on a bed
# 705 out of 5000 - 000000082807.jpg
# ---> a dog sitting at a table with a cake on it
# 706 out of 5000 - 000000082812.jpg
# ---> a group of people waiting for a train
# 707 out of 5000 - 000000082821.jpg
# ---> a row of pedal boats on a dock next to a building
# 708 out of 5000 - 000000082846.jpg
# ---> a red trolley on the street
# 709 out of 5000 - 000000082986.jpg
# ---> a man throwing a frisbee
# 710 out of 5000 - 000000083113.jpg
# ---> elephants in a zoo exhibit
# 711 out of 5000 - 000000083172.jpg
# ---> a woman playing tennis
# 712 out of 5000 - 000000083531.jpg
# ---> a group of sausages cooking on a grill
# 713 out of 5000 - 000000083540.jpg
# ---> a man skiing in the snow
# 714 out of 5000 - 000000084031.jpg
# ---> a baseball player swinging a bat
# 715 out of 5000 - 000000084170.jpg
# ---> a bus driving on a wet road
# 716 out of 5000 - 000000084241.jpg
# ---> women in a kitchen cooking
# 717 out of 5000 - 000000084270.jpg
# ---> people walking in a airport
# 718 out of 5000 - 000000084362.jpg
# ---> a cat sitting on a chair next to a baby
# 719 out of 5000 - 000000084431.jpg
# ---> a slice of pizza on a plate
# 720 out of 5000 - 000000084477.jpg
# ---> a chair and umbrella on a beach
# 721 out of 5000 - 000000084492.jpg
# ---> a man jumping on a rail with a skateboard
# 722 out of 5000 - 000000084650.jpg
# ---> a cat sitting on a suitcase
# 723 out of 5000 - 000000084664.jpg
# ---> a plate of food with a fork and a knife
# 724 out of 5000 - 000000084674.jpg
# ---> a woman holding a child and a boy
# 725 out of 5000 - 000000084752.jpg
# ---> a fighter jet on concrete pillars
# 726 out of 5000 - 000000085089.jpg
# ---> a group of people clinking wine glasses
# 727 out of 5000 - 000000085157.jpg
# ---> a group of people sitting around a table
# 728 out of 5000 - 000000085195.jpg
# ---> a piece of cake with a fork on a plate
# 729 out of 5000 - 000000085329.jpg
# ---> a woman with green eyes and piercings
# 730 out of 5000 - 000000085376.jpg
# ---> a motorcycle parked in a parking lot
# 731 out of 5000 - 000000085478.jpg
# ---> a polar bear swimming in water
# 732 out of 5000 - 000000085576.jpg
# ---> a roll of toilet paper on a bar
# 733 out of 5000 - 000000085665.jpg
# ---> a kite in the air
# 734 out of 5000 - 000000085682.jpg
# ---> a group of people on a snowy hill
# 735 out of 5000 - 000000085772.jpg
# ---> a man playing tennis on a court
# 736 out of 5000 - 000000085823.jpg
# ---> a group of zebras grazing on grass
# 737 out of 5000 - 000000085911.jpg
# ---> a kite floating in the water
# 738 out of 5000 - 000000086220.jpg
# ---> a car on the road
# 739 out of 5000 - 000000086483.jpg
# ---> a sign on a sidewalk
# 740 out of 5000 - 000000086582.jpg
# ---> a laptop on a table
# 741 out of 5000 - 000000086755.jpg
# ---> a person skiing down a snowy hill
# 742 out of 5000 - 000000086956.jpg
# ---> a group of people standing next to each other
# 743 out of 5000 - 000000087038.jpg
# ---> a man jumping on a skateboard with a skateboard on a ramp
# 744 out of 5000 - 000000087144.jpg
# ---> a man and woman sitting on a bench
# 745 out of 5000 - 000000087244.jpg
# ---> a fire hydrant is on the sidewalk
# 746 out of 5000 - 000000087470.jpg
# ---> a herd of cows walking on a road
# 747 out of 5000 - 000000087476.jpg
# ---> a man helping a child with a helmet
# 748 out of 5000 - 000000087742.jpg
# ---> a vase with peacock feathers in it
# 749 out of 5000 - 000000087875.jpg
# ---> a fire hydrant next to a bush
# 750 out of 5000 - 000000088040.jpg
# ---> a plate of food on a table
# 751 out of 5000 - 000000088218.jpg
# ---> a street sign on a pole
# 752 out of 5000 - 000000088250.jpg
# ---> elephants with tusks touching their trunks
# 753 out of 5000 - 000000088265.jpg
# ---> a horse pulling a carriage
# 754 out of 5000 - 000000088269.jpg
# ---> a bowl of soup and grilled cheese sandwich
# 755 out of 5000 - 000000088345.jpg
# ---> a woman smiling with lights on her head
# 756 out of 5000 - 000000088432.jpg
# ---> a fire hydrant is near the street
# 757 out of 5000 - 000000088462.jpg
# ---> a school bus on the street
# 758 out of 5000 - 000000088485.jpg
# ---> a man holding a frisbee
# 759 out of 5000 - 000000088848.jpg
# ---> a fire hydrant is painted yellow red and blue
# 760 out of 5000 - 000000088951.jpg
# ---> a man sitting on a bench with a cane
# 761 out of 5000 - 000000088970.jpg
# ---> a man swinging a tennis racket
# 762 out of 5000 - 000000089045.jpg
# ---> a piano in a living room
# 763 out of 5000 - 000000089078.jpg
# ---> a woman on a snowboard
# 764 out of 5000 - 000000089271.jpg
# ---> a cat wearing a hat
# 765 out of 5000 - 000000089296.jpg
# ---> a man swinging a baseball bat
# 766 out of 5000 - 000000089556.jpg
# ---> cars parked in a parking lot
# 767 out of 5000 - 000000089648.jpg
# ---> a group of people sitting in chairs using their phones
# 768 out of 5000 - 000000089670.jpg
# ---> a cake on a green plate
# 769 out of 5000 - 000000089697.jpg
# ---> a man and woman sitting on a bench
# 770 out of 5000 - 000000089761.jpg
# ---> a toilet next to a tree
# 771 out of 5000 - 000000089880.jpg
# ---> two dogs playing on grass
# 772 out of 5000 - 000000090003.jpg
# ---> dogs playing with a frisbee
# 773 out of 5000 - 000000090062.jpg
# ---> a cow standing in front of a wood shed
# 774 out of 5000 - 000000090108.jpg
# ---> a bathroom with a sink and a bathtub
# 775 out of 5000 - 000000090155.jpg
# ---> a train on the tracks
# 776 out of 5000 - 000000090208.jpg
# ---> a green double decker bus parked on a road
# 777 out of 5000 - 000000090284.jpg
# ---> a woman playing tennis on a clay court
# 778 out of 5000 - 000000090631.jpg
# ---> a colorful airplane flying in the sky
# 779 out of 5000 - 000000090891.jpg
# ---> a group of men standing in a fruit shop
# 780 out of 5000 - 000000090956.jpg
# ---> a person skiing down a slope
# 781 out of 5000 - 000000091406.jpg
# ---> a group of women standing in front of pizza boxes
# 782 out of 5000 - 000000091495.jpg
# ---> a baseball player jumping into the air
# 783 out of 5000 - 000000091500.jpg
# ---> a group of men playing video games
# 784 out of 5000 - 000000091615.jpg
# ---> a kitchen with granite counter tops and stainless steel appliances
# 785 out of 5000 - 000000091619.jpg
# ---> a stop sign on a pole
# 786 out of 5000 - 000000091654.jpg
# ---> a bowl of noodles with meat and green onions
# 787 out of 5000 - 000000091779.jpg
# ---> a group of hot dogs with chili peppers and onions
# 788 out of 5000 - 000000091921.jpg
# ---> a zebras in a zoo exhibit
# 789 out of 5000 - 000000092053.jpg
# ---> a table with plates of food and drinks
# 790 out of 5000 - 000000092091.jpg
# ---> a little girl brushing her teeth with a teddy bear
# 791 out of 5000 - 000000092124.jpg
# ---> a bathroom with a pink shower curtain
# 792 out of 5000 - 000000092177.jpg
# ---> a cake with palm trees and a banner
# 793 out of 5000 - 000000092416.jpg
# ---> a man in a suit holding a beer
# 794 out of 5000 - 000000092660.jpg
# ---> a pizza with broccoli and cheese on a pan
# 795 out of 5000 - 000000092839.jpg
# ---> a polar bear lying on a rock
# 796 out of 5000 - 000000092939.jpg
# ---> a man and woman cutting a cake
# 797 out of 5000 - 000000093154.jpg
# ---> a street with cars and signs on it
# 798 out of 5000 - 000000093261.jpg
# ---> a man sitting on a beach with a kite
# 799 out of 5000 - 000000093353.jpg
# ---> a hand holding a hot dog bun
# 800 out of 5000 - 000000093437.jpg
# ---> an old man wearing a hat and glasses
# 801 out of 5000 - 000000093717.jpg
# ---> a man doing a trick on a skateboard
# 802 out of 5000 - 000000093965.jpg
# ---> zebras in a field of grass
# 803 out of 5000 - 000000094157.jpg
# ---> a tall building with a clock on it
# 804 out of 5000 - 000000094185.jpg
# ---> a teddy bear standing outside a store
# 805 out of 5000 - 000000094326.jpg
# ---> a statue of a man reading a newspaper
# 806 out of 5000 - 000000094336.jpg
# ---> a cat sitting in a sink
# 807 out of 5000 - 000000094614.jpg
# ---> a man skiing down a slope
# 808 out of 5000 - 000000094751.jpg
# ---> a traffic light on a street
# 809 out of 5000 - 000000094852.jpg
# ---> an elephant and calf in tall grass
# 810 out of 5000 - 000000094871.jpg
# ---> a girl feeding sheep on a stone path
# 811 out of 5000 - 000000094944.jpg
# ---> a snowboarder kneeling on the snow
# 812 out of 5000 - 000000095069.jpg
# ---> a building with a clock on top
# 813 out of 5000 - 000000095155.jpg
# ---> a collage of a snowboarder
# 814 out of 5000 - 000000095707.jpg
# ---> a cake on a foil sheet
# 815 out of 5000 - 000000095786.jpg
# ---> a close-up of some pottery
# 816 out of 5000 - 000000095843.jpg
# ---> a double decker bus parked on the side of the road
# 817 out of 5000 - 000000095862.jpg
# ---> a baseball game with a crowd watching
# 818 out of 5000 - 000000095899.jpg
# ---> a stop sign next to a blue sign
# 819 out of 5000 - 000000096001.jpg
# ---> a cat figurine and an umbrella on a table
# 820 out of 5000 - 000000096427.jpg
# ---> a boy holding a tennis racket
# 821 out of 5000 - 000000096493.jpg
# ---> a child sitting on a couch with a remote control
# 822 out of 5000 - 000000096549.jpg
# ---> a large airplane on a runway
# 823 out of 5000 - 000000096825.jpg
# ---> a man skiing on a snowy hill
# 824 out of 5000 - 000000096960.jpg
# ---> a polar bear swimming under water
# 825 out of 5000 - 000000097022.jpg
# ---> a kitchen with wooden cabinets and appliances
# 826 out of 5000 - 000000097230.jpg
# ---> elephants in the wild
# 827 out of 5000 - 000000097278.jpg
# ---> a person is standing on snowboard
# 828 out of 5000 - 000000097337.jpg
# ---> a living room with a tv and a vase on a glass table
# 829 out of 5000 - 000000097585.jpg
# ---> a wall with colorful glass vases and flowers
# 830 out of 5000 - 000000097679.jpg
# ---> a couple of cars parked in a lot
# 831 out of 5000 - 000000097924.jpg
# ---> a group of people lifting a horse
# 832 out of 5000 - 000000097988.jpg
# ---> a man standing under a banner
# 833 out of 5000 - 000000097994.jpg
# ---> a desk with several computers and a laptop
# 834 out of 5000 - 000000098018.jpg
# ---> a room with a door and a pot
# 835 out of 5000 - 000000098261.jpg
# ---> a group of birds on a branch
# 836 out of 5000 - 000000098287.jpg
# ---> a kid playing baseball in the sand
# 837 out of 5000 - 000000098392.jpg
# ---> a clock tower in a city
# 838 out of 5000 - 000000098497.jpg
# ---> a sign on a building
# 839 out of 5000 - 000000098520.jpg
# ---> a plane on the runway
# 840 out of 5000 - 000000098633.jpg
# ---> a cake with strawberries on top
# 841 out of 5000 - 000000098716.jpg
# ---> a man sitting on a bench
# 842 out of 5000 - 000000098839.jpg
# ---> a cat watching a television
# 843 out of 5000 - 000000098853.jpg
# ---> a man swinging a tennis racket on a clay court with people watching
# 844 out of 5000 - 000000099024.jpg
# ---> a person is making a kite
# 845 out of 5000 - 000000099039.jpg
# ---> a pizza and wine on a table
# 846 out of 5000 - 000000099053.jpg
# ---> a bowl of noodles and meat
# 847 out of 5000 - 000000099054.jpg
# ---> a group of airplanes at an airport
# 848 out of 5000 - 000000099114.jpg
# ---> people walking on a street
# 849 out of 5000 - 000000099182.jpg
# ---> a man reading a book
# 850 out of 5000 - 000000099242.jpg
# ---> a man skiing down a snowy hill
# 851 out of 5000 - 000000099428.jpg
# ---> a stack of electronic devices
# 852 out of 5000 - 000000099810.jpg
# ---> a boy sitting in a chair eating donuts
# 853 out of 5000 - 000000100238.jpg
# ---> a group of people holding frisbees
# 854 out of 5000 - 000000100274.jpg
# ---> a train is going down the tracks
# 855 out of 5000 - 000000100283.jpg
# ---> a stop sign on a pole
# 856 out of 5000 - 000000100428.jpg
# ---> a man pulling a tie around a man's neck
# 857 out of 5000 - 000000100489.jpg
# ---> a bird perched on a branch
# 858 out of 5000 - 000000100510.jpg
# ---> a person on a horse jumping a hurdle
# 859 out of 5000 - 000000100582.jpg
# ---> a pizza with greens and prosciutto
# 860 out of 5000 - 000000100624.jpg
# ---> a woman talking on a cell phone
# 861 out of 5000 - 000000100723.jpg
# ---> a group of people marching in a street with signs
# 862 out of 5000 - 000000101022.jpg
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
df.sample(20)
# Out:
#            filename                                        caption  \
# 0  000000001425.jpg                          a sandwich on a plate
# 0  000000001490.jpg           a person on a surfboard in the water
# 0  000000000285.jpg                    a bear sitting in the grass
# 0  000000000139.jpg                  a woman standing in a kitchen
# 0  000000001761.jpg               an airplane flying over a bridge
# 0  000000001000.jpg           a group of people posing for a photo
# 0  000000001503.jpg                           a computer on a desk
# 0  000000001296.jpg                a woman looking at a cell phone
# 0  000000000632.jpg                  a bedroom with a large window
# 0  000000000724.jpg                          a stop sign on a pole
# 0  000000000776.jpg                         a group of teddy bears
# 0  000000001675.jpg                        a cat lying in a laptop
# 0  000000000785.jpg                     a woman skiing on the snow
# 0  000000000872.jpg              a baseball player running to base
# 0  000000001584.jpg            a red double decker bus on a street
# 0  000000001268.jpg  a couple of people taking a picture of a swan
# 0  000000001532.jpg             a freeway with many cars and signs
# 0  000000001353.jpg             a group of children riding a train
# 0  000000000885.jpg                  a man holding a tennis racket
# 0  000000000802.jpg                a kitchen with white appliances
#
#                                      object_captions  \
# 0  a close-up of a sandwich, close-up of a white ...
# 0  a person on a surfboard in the water, a person...
# 0                        a bear sitting in the grass
# 0  a chair with legs and a red cushion, a person ...
# 0  a plane flying in the sky, an airplane flying ...
# 0  a person holding a trophy, a person wearing a ...
# 0  a blurry image of a grey couch, a laptop on a ...
# 0  a close-up of a phone, a woman looking at a ce...
# 0  a blue blanket on a bed, a plant in a pot, a b...
# 0  a tree next to a road, a stop sign on a pole, ...
# 0  a close-up of a brown teddy bear, a stuffed be...
# 0  a cat lying in a refrigerator, a close-up of a...
# 0                         a woman skiing on the snow
# 0  a man running with his hands on his hips, a ba...
# 0  a red double decker bus, a person in a white s...
# 0  a close-up of a woman's handbag, a couple of p...
# 0  a black jeep with spare tire, a taxi on the st...
# 0  a close-up of a child's face, a person sitting...
# 0  a man playing tennis on a tennis court, a woma...
# 0  a white stove with four burners, a kitchen wit...
#
#                                                 tags
# 0  fast food, sandwich, indoor, black, food, coff...
# 0  surfing, water, surfing equipment, surfboard, ...
# 0  brown bear, grass, brown, kodiak bear, terrest...
# 0  room, hardwood, couch, television, table, scen...
# 0  flight, vehicle, water, bridge, outdoor, plane...
# 0  tennis, group, child, adult, court, person, ou...
# 0  computer terminal, personal computer hardware,...
# 0  nail, watch, black hair, street, phone, clothi...
# 0  room, bed sheet, shelving, bookcase, scene, ca...
# 0  road, tree, street, stop, intersection, signag...
# 0  fabric, brown, indoor, toy, teddy bear, stuffe...
# 0  indoor, cat, black, small to medium-sized cats...
# 0  recreation, ski pole, riding, person, outdoor,...
# 0  baseball uniform, baseball protective gear, sp...
# 0  mode of transport, city, road, vehicle, double...
# 0  lake, people, looking, pier, water, dock, stre...
# 0  outdoor, wheel, sign, freeway, road, expresswa...
# 0  footwear, indoor, clothing, bumper car, woman,...
# 0  tennis, playing, tennis player, rackets, court...
# 0  room, door, oven, refrigerator, home appliance...

# %%
# Save results
df.to_parquet("azurecv_image_analyzes.parquet")
