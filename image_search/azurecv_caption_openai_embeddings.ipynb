# %% [markdown]
# # Get captions, dense captions and tags from Azure Computer Vision

# %%
# !pip install azure-ai-vision --user

# %%
# imports
import requests
import os
from dotenv import load_dotenv
import pandas as pd
import azure.ai.vision as sdk
import time

# %%
# Load envs
load_dotenv('.env')

# Azure Computer Vision
key = os.getenv("azure_cv_key")
endpoint = os.getenv("azure_cv_endpoint")

# Images to process
image_dir = './val2017/'

# Get Azure Computer Vision client
service_options = sdk.VisionServiceOptions(endpoint, key)

# %%
def analyze_image(imagefile):
    # Set source file
    vision_source = sdk.VisionSource(filename=imagefile)

    # Set analysis options (enable features)
    analysis_options = sdk.ImageAnalysisOptions()

    analysis_options.features = (
        sdk.ImageAnalysisFeature.CAPTION |
        # sdk.ImageAnalysisFeature.DENSE_CAPTIONS |
        sdk.ImageAnalysisFeature.TAGS
    )

    # Analyze the image
    image_analyzer = sdk.ImageAnalyzer(service_options, vision_source, analysis_options)
    result = image_analyzer.analyze()

    return result

# %%
df = pd.DataFrame()
num_files = len(os.listdir(image_dir))

# Iterate over images
for i, filename in enumerate(os.listdir(image_dir)):
    print(f"{i} out of {num_files} - {filename}")

    # Analyze image with retries
    for retries in range(10):
        result = analyze_image(image_dir + filename)
        if result.reason == sdk.ImageAnalysisResultReason.ANALYZED:
            break # Success
        print(f"Will retry {filename} for {retries+1} time")
        if retries == 9:
            raise Exception(f"Failed to analyze {filename} after 10 retries")
        time.sleep(63)
    
    # Parse results
    caption = result.caption.content
    # object_captions = ", ".join(set(object.content for object in result.dense_captions))
    tags = ", ".join(set(object.name for object in result.tags))

    # Store results
    result = { "filename": filename, "caption": caption, "tags": tags }
    # result = { "filename": filename, "caption": caption, "object_captions": object_captions, "tags": tags }
    row = pd.DataFrame(result, index=[0])
    df = pd.concat([df, row], axis=0)
    print(f"---> {caption}")

# %%
df.sample(20)
# Out:
#            filename                                        caption  \
# 0  000000001425.jpg                          a sandwich on a plate
# 0  000000001490.jpg           a person on a surfboard in the water
# 0  000000000285.jpg                    a bear sitting in the grass
# 0  000000000139.jpg                  a woman standing in a kitchen
# 0  000000001761.jpg               an airplane flying over a bridge
# 0  000000001000.jpg           a group of people posing for a photo
# 0  000000001503.jpg                           a computer on a desk
# 0  000000001296.jpg                a woman looking at a cell phone
# 0  000000000632.jpg                  a bedroom with a large window
# 0  000000000724.jpg                          a stop sign on a pole
# 0  000000000776.jpg                         a group of teddy bears
# 0  000000001675.jpg                        a cat lying in a laptop
# 0  000000000785.jpg                     a woman skiing on the snow
# 0  000000000872.jpg              a baseball player running to base
# 0  000000001584.jpg            a red double decker bus on a street
# 0  000000001268.jpg  a couple of people taking a picture of a swan
# 0  000000001532.jpg             a freeway with many cars and signs
# 0  000000001353.jpg             a group of children riding a train
# 0  000000000885.jpg                  a man holding a tennis racket
# 0  000000000802.jpg                a kitchen with white appliances
#
#                                      object_captions  \
# 0  a close-up of a sandwich, close-up of a white ...
# 0  a person on a surfboard in the water, a person...
# 0                        a bear sitting in the grass
# 0  a chair with legs and a red cushion, a person ...
# 0  a plane flying in the sky, an airplane flying ...
# 0  a person holding a trophy, a person wearing a ...
# 0  a blurry image of a grey couch, a laptop on a ...
# 0  a close-up of a phone, a woman looking at a ce...
# 0  a blue blanket on a bed, a plant in a pot, a b...
# 0  a tree next to a road, a stop sign on a pole, ...
# 0  a close-up of a brown teddy bear, a stuffed be...
# 0  a cat lying in a refrigerator, a close-up of a...
# 0                         a woman skiing on the snow
# 0  a man running with his hands on his hips, a ba...
# 0  a red double decker bus, a person in a white s...
# 0  a close-up of a woman's handbag, a couple of p...
# 0  a black jeep with spare tire, a taxi on the st...
# 0  a close-up of a child's face, a person sitting...
# 0  a man playing tennis on a tennis court, a woma...
# 0  a white stove with four burners, a kitchen wit...
#
#                                                 tags
# 0  fast food, sandwich, indoor, black, food, coff...
# 0  surfing, water, surfing equipment, surfboard, ...
# 0  brown bear, grass, brown, kodiak bear, terrest...
# 0  room, hardwood, couch, television, table, scen...
# 0  flight, vehicle, water, bridge, outdoor, plane...
# 0  tennis, group, child, adult, court, person, ou...
# 0  computer terminal, personal computer hardware,...
# 0  nail, watch, black hair, street, phone, clothi...
# 0  room, bed sheet, shelving, bookcase, scene, ca...
# 0  road, tree, street, stop, intersection, signag...
# 0  fabric, brown, indoor, toy, teddy bear, stuffe...
# 0  indoor, cat, black, small to medium-sized cats...
# 0  recreation, ski pole, riding, person, outdoor,...
# 0  baseball uniform, baseball protective gear, sp...
# 0  mode of transport, city, road, vehicle, double...
# 0  lake, people, looking, pier, water, dock, stre...
# 0  outdoor, wheel, sign, freeway, road, expresswa...
# 0  footwear, indoor, clothing, bumper car, woman,...
# 0  tennis, playing, tennis player, rackets, court...
# 0  room, door, oven, refrigerator, home appliance...

# %%
# Save results
df.to_parquet("azurecv_image_analyzes.parquet")
